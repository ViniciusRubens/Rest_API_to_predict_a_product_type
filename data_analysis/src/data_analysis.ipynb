# %% [markdown]
# # Project 3

# %% [markdown]
# ## Título

# %%
# !pip install -q -U watermark

# %%
# %reload_ext watermark
# %watermark -a "Vinicius Rubens França de Oliveira"
# Out:
# Author: Vinicius Rubens França de Oliveira

# %%
import pandas as pd
import pyarrow as pa
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading Data

# %%
df_products = pd.read_csv("../../dataset/synthetic_shipping_data.csv")
df_products.head()
# Out:
#    id  package_weight_gr   package_size product_type
# 0   1             213.94  Small Package   Smartphone
# 1   2             513.72  Small Package       Tablet
# 2   3             578.34  Small Package       Tablet
# 3   4              96.64  Small Package   Smartwatch
# 4   5             103.03  Small Package   Smartwatch

# %% [markdown]
# ### Feature engineering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   package_weight_gr  5000 non-null   float64
#  1   package_size       5000 non-null   object
#  2   product_type       5000 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 117.3+ KB

# %%
# Lets see each values for object columns
df['package_size'].value_counts()
# Out:
# package_size
# Small Package    3750
# Large Package    1250
# Name: count, dtype: int64

# %%
# Output category
df['product_type'].value_counts()
# Out:
# product_type
# Notebook      1256
# Smartphone    1254
# Smartwatch    1248
# Tablet        1242
# Name: count, dtype: int64

# %%
# %watermark -a "Vinicius Rubens"
# Out:
# Author: Vinicius Rubens
